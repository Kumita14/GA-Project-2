# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a serious of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer:
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer:
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
movies.duration.mean()
# Out:
# 120.97957099080695

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:
movies.title[movies.duration.sort_values()] #64(shortest:Wall E), 242(longest:The Celebration)
# Out:
# 64                   WALL-E
# 66      Munna Bhai M.B.B.S.
# 67          American Beauty
# 68                 Das Boot
# 68                 Das Boot
#                ...
# 220                  Gandhi
# 224        The Wizard of Oz
# 229    Strangers on a Train
# 238          Before Sunrise
# 242         The Celebration
# Name: title, Length: 979, dtype: object

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer:
movies.duration.plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:
movies.duration.plot(kind='box')
#min value=some num below 75
#max value=some num between 175 and 200
#first quartile=some num between 100 and 125
#second quartile/median=some num between 125 and 150
#third quartile=slightly above 100
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Intermediate level

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
# Answer:
movies.content_rating.value_counts().sort_values()
# Out:
# TV-MA          1
# GP             3
# X              4
# PASSED         7
# NC-17          7
# G             32
# UNRATED       38
# APPROVED      47
# NOT RATED     65
# PG           123
# PG-13        189
# R            460
# Name: content_rating, dtype: int64

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:
movies.content_rating.value_counts().sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Content Rating')
plt.ylabel('Movie Counts')
plt.title('Content Rating vs Movie Counts')
# Out:
# Text(0.5, 1.0, 'Content Rating vs Movie Counts')

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
# Answer:
movies.content_rating.replace('NOT RATED', 'UNRATED', inplace=True)
movies.content_rating.replace('APPROVED', 'UNRATED', inplace=True)
movies.content_rating.replace('PASSED', 'UNRATED', inplace=True)
movies.content_rating.replace('GP', 'UNRATED', inplace=True)

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:
movies.content_rating.replace(['X', 'TV-MA'], 'NC-17', inplace=True)

# %%
pd.set_option("max_rows", None)
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:
movies[movies.content_rating.isnull()]
#187, 649, 7.4
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
movies.at[(187,649), 'content_rating'] = 'PG'
movies.at[936, 'content_rating'] = 'PG-13'

# %%
movies[movies.content_rating.isnull()]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer:
movies.star_rating[movies.duration>=120].mean()
# Out:
# 7.948898678414082

# %%
movies.star_rating[movies.duration<120].mean()
# Out:
# 7.838666666666657

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:
movies.plot(kind='scatter', x='star_rating', y='duration', alpha=0.2)
#graph below shows that the plots are concentrated at the bottom right
#means most movies less than 150 mins tend to get ratings less than 8.5
# Out:
# <AxesSubplot:xlabel='star_rating', ylabel='duration'>

# %%
movies.boxplot(column='duration', by='star_rating');
#movies below 125 mins is most likely to get a rating

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
#answer
movies.groupby('genre').duration.agg(['mean']).sort_index()
# Out:
#                  mean
# genre
# Action     126.485294
# Adventure  134.840000
# Animation   96.596774
# Biography  131.844156
# Comedy     107.602564
# Crime      122.298387
# Drama      126.539568
# Family     107.500000
# Fantasy    112.000000
# Film-Noir   97.333333
# History     66.000000
# Horror     102.517241
# Mystery    115.625000
# Sci-Fi     109.000000
# Thriller   114.200000
# Western    136.666667

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:
movies.boxplot(column='duration', by='content_rating');
#movies below the duration 125 tends to get more ratings

# %%
movies.plot(kind='scatter', x='content_rating', y='duration', alpha=0.2)
#R gets most rating, NC-17 gets least rating
# Out:
# <AxesSubplot:xlabel='content_rating', ylabel='duration'>

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
# Answer:
movies.groupby('genre').star_rating.agg(['max']).sort_values('max', ascending=False)
# Out:
#            max
# genre
# Crime      9.3
# Action     9.0
# Adventure  8.9
# Biography  8.9
# Drama      8.9
# Western    8.9
# Animation  8.6
# Comedy     8.6
# Horror     8.6
# Mystery    8.6
# Film-Noir  8.3
# Sci-Fi     8.2
# History    8.0
# Thriller   8.0
# Family     7.9
# Fantasy    7.7

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
# Answer:
movies.title.duplicated().sum()
# Out:
# 4

# %%
movies[movies.title.duplicated()]
# Out:
#      star_rating                            title content_rating      genre  \
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 905          7.5                          Dracula              R     Horror
# 924          7.5                   Les Miserables          PG-13      Crime
# 936          7.4                        True Grit          PG-13  Adventure
#
#      duration                                        actors_list
# 482       152  [u'Michael Nyqvist', u'Noomi Rapace', u'Ewa Fr...
# 905       128  [u'Gary Oldman', u'Winona Ryder', u'Anthony Ho...
# 924       134  [u'Liam Neeson', u'Geoffrey Rush', u'Uma Thurm...
# 936       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
movies.loc[movies.title.duplicated(keep=False), :]
# Out:
#      star_rating                            title content_rating      genre  \
# 466          7.9  The Girl with the Dragon Tattoo              R      Crime
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 662          7.7                        True Grit          PG-13  Adventure
# 678          7.7                   Les Miserables          PG-13      Drama
# 703          7.6                          Dracula        UNRATED     Horror
# 905          7.5                          Dracula              R     Horror
# 924          7.5                   Les Miserables          PG-13      Crime
# 936          7.4                        True Grit          PG-13  Adventure
#
#      duration                                        actors_list
# 466       158  [u'Daniel Craig', u'Rooney Mara', u'Christophe...
# 482       152  [u'Michael Nyqvist', u'Noomi Rapace', u'Ewa Fr...
# 662       110  [u'Jeff Bridges', u'Matt Damon', u'Hailee Stei...
# ...

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
# Answer:

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:
movies.groupby('genre').star_rating.mean()[movies.genre.value_counts() >= 10]
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!

# %%
movies.actors_list.describe()
#same actors, 6 different movies
# Out:
# count                                                   979
# unique                                                  969
# top       [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                      6
# Name: actors_list, dtype: object
